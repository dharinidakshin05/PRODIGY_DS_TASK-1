# %% [markdown]
# <a href="https://colab.research.google.com/github/dharinidakshin05/PRODIGY_DS_TASK-1/blob/main/dharini_task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !https://github.com/dharinidakshin05/PRODIGY_DS_TASK-1.git
# Out:
# /bin/bash: line 1: https://github.com/dharinidakshin05/PRODIGY_DS_TASK-1.git: No such file or directory

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load data as xlsx file
df = pd.read_excel("/content/age and gender population.xlsx")

# Create a histogram
plt.hist(df['AGE'], bins=10, edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Create a bar chart
gender_counts = df['GENDER'].value_counts()
plt.bar(gender_counts.index, gender_counts.values)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
